# %% [markdown]
# # Introduction to Pandas
#
#   - In this section of the training, we will learn how to use pandas for data analysis.
#   - You can think of pandas as an extremely powerful version of Excel, with a lot more features.
#
# ### In this section of the course, we will learn:
#
# * Introduction to Pandas
# * Series
# * DataFrames
# * Missing Data
# * GroupBy
# * Merging,Joining,and Concatenating
# * Operations
# * Data Input and Output

# %% [markdown]
# ___
